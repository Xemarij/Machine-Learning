# %% [markdown]
# <a href="https://colab.research.google.com/github/Xemarij/Machine-Learning/blob/main/Machine_Learning_Visualizations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opendatasets

# %%
import opendatasets as od
import pandas
#Importing an open dataset from Kaggle
od.download("https://www.kaggle.com/datasets/midhundasl/co2-emission-of-cars-dataset")
# Out:
# Dataset URL: https://www.kaggle.com/datasets/midhundasl/co2-emission-of-cars-dataset
# ...
# 100%|██████████| 635/635 [00:00<00:00, 184kB/s]

# %%
# !ls
# Out:
# co2-emission-of-cars-dataset  drive  kaggle.json  sample_data

# %%
#List the contents of the Google Drive
import os
print(os.listdir('/content/drive/My Drive'))
# Out:
# ['Colab Notebooks', 'Tauqeer-Khurram-Tech support (CV) (4).pdf', 'Tauqeer-Khurram-Tech support (CV) (3).pdf', 'Tauqeer-Khurram-Tech support (CV) (2).pdf', 'Tauqeer-Khurram-Tech support (CV) (1).pdf', 'Copy of eCommerce Checklist.gsheet', 'Keyword Stats 2024-07-23 at 11_45_32.gsheet', 'Portfolio.gsite', 'Make More Money Online.gsite', 'Guest Post Tracking Sheet.gsheet', 'Target Guest Post Site Info .gsheet', 'SpeetTest - Tauqeer Khurram.jpg', 'Name Search.gsheet', 'Tauqeer-Khurram-Tech support (CV).pdf', 'Name 10 US universities where it is easy to get ad....gdoc', 'Train4']

# %%
#importing Google drive to Google Colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
# ['Colab Notebooks', 'Tauqeer-Khurram-Tech support (CV) (4).pdf', 'Tauqeer-Khurram-Tech support (CV) (3).pdf', 'Tauqeer-Khurram-Tech support (CV) (2).pdf', 'Tauqeer-Khurram-Tech support (CV) (1).pdf', 'Copy of eCommerce Checklist.gsheet', 'Keyword Stats 2024-07-23 at 11_45_32.gsheet', 'Portfolio.gsite', 'Make More Money Online.gsite', 'Guest Post Tracking Sheet.gsheet', 'Target Guest Post Site Info .gsheet', 'SpeetTest - Tauqeer Khurram.jpg', 'Name Search.gsheet', 'Tauqeer-Khurram-Tech support (CV).pdf', 'Name 10 US universities where it is easy to get ad....gdoc']

# %%
# !cp -r "/content/co2-emission-of-cars-dataset" "/content/drive/My Drive/Train4"

# %%
import sklearn as sk
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
csvFile = pd.read_csv('/content/drive/MyDrive/Train4/DATA.csv')

# %%
csvFile.head()
# Out:
#           Car       Model  Volume  Weight  CO2  Unnamed: 5
# 0      Toyota        Aygo    1000     790   99         NaN
# 1  Mitsubishi  Space Star    1200    1160   95         NaN
# 2       Skoda      Citigo    1000     929   95         NaN
# 3        Fiat         500     900     865   90         NaN
# 4        Mini      Cooper    1500    1140  105         NaN

# %% [markdown]
# ### **Relation Visualization**

# %%
import matplotlib.pyplot as plt
csvFile.plot(kind = 'scatter', x='Volume', y='CO2', figsize=(20,7), grid=True, fontsize=15)
# Out:
# <Axes: xlabel='Volume', ylabel='CO2'>

# %% [markdown]
# # The Scatter plot shows the correlation between the 'Volume' and the 'CO2' emissions. We see that as the Volume increases the CO2 emissions also increase.

# %%
csvFile['CO2'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # A pivot table is created using the y-axis values on the column and the x-axis values in the place of cells.

# %% [markdown]
# A

# %%
csvFile.pivot(columns='Car', values='CO2')
# Out:
# Car   Audi    BMW  Fiat   Ford  Honda  Hundai  Hyundai  Mazda  Mercedes  \
# 0      NaN    NaN   NaN    NaN    NaN     NaN      NaN    NaN       NaN
# 1      NaN    NaN   NaN    NaN    NaN     NaN      NaN    NaN       NaN
# 2      NaN    NaN   NaN    NaN    NaN     NaN      NaN    NaN       NaN
# 3      NaN    NaN  90.0    NaN    NaN     NaN      NaN    NaN       NaN
# 4      NaN    NaN   NaN    NaN    NaN     NaN      NaN    NaN       NaN
# 5      NaN    NaN   NaN    NaN    NaN     NaN      NaN    NaN       NaN
# 6      NaN    NaN   NaN    NaN    NaN     NaN      NaN    NaN       NaN
# 7      NaN    NaN   NaN    NaN    NaN     NaN      NaN    NaN      92.0
# 8      NaN    NaN   NaN   98.0    NaN     NaN      NaN    NaN       NaN
# 9     99.0    NaN   NaN    NaN    NaN     NaN      NaN    NaN       NaN
# 10     NaN    NaN   NaN    NaN    NaN     NaN     99.0    NaN       NaN
# 11     NaN    NaN   NaN    NaN    NaN     NaN      NaN    NaN       NaN
# ...

# %%
csvFile.pivot(columns='Car', values='CO2').plot(kind='box', figsize=(20,7), fontsize=15)
# Out:
# <Axes: >

# %% [markdown]
# # The box plot shows that Mercedez has the highest carbon emission of all the cars.

# %% [markdown]
# ### **Compostion Visualization**

# %%
csvFile.groupby('CO2')['Car'].value_counts()
# Out:
# CO2  Car
# 90   Fiat          1
#      Skoda         1
# 92   Mercedes      1
# 94   Ford          1
#      Honda         1
# 95   Mitsubishi    1
#      Skoda         1
# 97   Opel          1
#      Hundai        1
# 98   Ford          1
# 99   Volvo         1
#      Toyota        1
#      Skoda         1
#      Audi          1
#      BMW           1
#      Ford          1
#      Hyundai       1
#      Mercedes      1
#      Opel          1
# 101  Suzuki        1
# 102  Mercedes      1
# 104  Audi          1
#      Ford          1
#      Mazda         1
#      Skoda         1
# 105  Ford          1
#      Mini          1
#      VW            1
# 108  BMW           1
# 109  Opel          1
#      Volvo         1
# 114  Audi          1
#      BMW           1
# 115  Mercedes      1
# 117  Volvo         1
# 120  Mercedes      1
# Name: count, dtype: int64

# %%
csvFile.groupby('CO2')['Car'].value_counts().unstack().plot(kind='bar',stacked=True, figsize=(20,7), fontsize=15)
# Out:
# <Axes: xlabel='CO2'>

# %%
csvFile.groupby('CO2')['Car'].value_counts().unstack()
# Out:
# Car  Audi  BMW  Fiat  Ford  Honda  Hundai  Hyundai  Mazda  Mercedes  Mini  \
# CO2
# 90    NaN  NaN   1.0   NaN    NaN     NaN      NaN    NaN       NaN   NaN
# 92    NaN  NaN   NaN   NaN    NaN     NaN      NaN    NaN       1.0   NaN
# 94    NaN  NaN   NaN   1.0    1.0     NaN      NaN    NaN       NaN   NaN
# 95    NaN  NaN   NaN   NaN    NaN     NaN      NaN    NaN       NaN   NaN
# 97    NaN  NaN   NaN   NaN    NaN     1.0      NaN    NaN       NaN   NaN
# 98    NaN  NaN   NaN   1.0    NaN     NaN      NaN    NaN       NaN   NaN
# 99    1.0  1.0   NaN   1.0    NaN     NaN      1.0    NaN       1.0   NaN
# 101   NaN  NaN   NaN   NaN    NaN     NaN      NaN    NaN       NaN   NaN
# 102   NaN  NaN   NaN   NaN    NaN     NaN      NaN    NaN       1.0   NaN
# 104   1.0  NaN   NaN   1.0    NaN     NaN      NaN    1.0       NaN   NaN
# 105   NaN  NaN   NaN   1.0    NaN     NaN      NaN    NaN       NaN   1.0
# 108   NaN  1.0   NaN   NaN    NaN     NaN      NaN    NaN       NaN   NaN
# ...
